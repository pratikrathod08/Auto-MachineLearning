# %%
import pandas as pd 
import numpy as np 

path = r"D:\PRATIK\education\DATASET\csv\car_buyers.csv"

df = pd.read_csv(path)

# %%
df.head()
# Out:
#       ID Marital Status  Gender   Income  Children        Education  \
# 0  12496        Married  Female  40000.0       1.0        Bachelors
# 1  24107        Married    Male  30000.0       3.0  Partial College
# 2  14177        Married    Male  80000.0       5.0  Partial College
# 3  24381         Single     NaN  70000.0       0.0        Bachelors
# 4  25597         Single    Male  30000.0       0.0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# 1        Clerical        Yes   1.0        0-1 Miles   Europe  43.0
# 2    Professional         No   2.0        2-5 Miles   Europe  60.0
# 3    Professional        Yes   1.0       5-10 Miles  Pacific  41.0
# 4        Clerical         No   0.0        0-1 Miles   Europe  36.0
#
#   Purchased car
# 0            No
# 1            No
# 2            No
# 3           Yes
# 4           Yes

# %%
df['purchase_status'] = df['Purchased car'].map({'Yes': 1, 'No': 0})

# %%
df.head()
# Out:
#       ID Marital Status  Gender   Income  Children        Education  \
# 0  12496        Married  Female  40000.0       1.0        Bachelors
# 1  24107        Married    Male  30000.0       3.0  Partial College
# 2  14177        Married    Male  80000.0       5.0  Partial College
# 3  24381         Single     NaN  70000.0       0.0        Bachelors
# 4  25597         Single    Male  30000.0       0.0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# 1        Clerical        Yes   1.0        0-1 Miles   Europe  43.0
# 2    Professional         No   2.0        2-5 Miles   Europe  60.0
# 3    Professional        Yes   1.0       5-10 Miles  Pacific  41.0
# 4        Clerical         No   0.0        0-1 Miles   Europe  36.0
#
#   Purchased car  purchase_status
# 0            No                0
# 1            No                0
# 2            No                0
# 3           Yes                1
# 4           Yes                1

# %%
df.drop(columns=['ID', 'Purchased car'], inplace=True)

# %%
df.head()
# Out:
#   Marital Status  Gender   Income  Children        Education      Occupation  \
# 0        Married  Female  40000.0       1.0        Bachelors  Skilled Manual
# 1        Married    Male  30000.0       3.0  Partial College        Clerical
# 2        Married    Male  80000.0       5.0  Partial College    Professional
# 3         Single     NaN  70000.0       0.0        Bachelors    Professional
# 4         Single    Male  30000.0       0.0        Bachelors        Clerical
#
#   Home Owner  Cars Commute Distance   Region   Age  purchase_status
# 0        Yes   0.0        0-1 Miles   Europe  42.0                0
# 1        Yes   1.0        0-1 Miles   Europe  43.0                0
# 2         No   2.0        2-5 Miles   Europe  60.0                0
# 3        Yes   1.0       5-10 Miles  Pacific  41.0                1
# 4         No   0.0        0-1 Miles   Europe  36.0                1

# %%
df.to_csv("car_buyers.csv", index=False)

# %%
from auto_machinelearning.ml.preprocessor.preprocess import AutoPreprocess

# Create the processor instance
processor = AutoPreprocess(
    path=r"research\data\car_buyers.csv",                                        # Path to the file
    file_type="csv",                                        # "csv" or "excel"
    store_path="output/processed.csv",                      # Path to save the result
    target_column="purchase_status",                                  # Target column name
    preprocessor_store_path="output/preprocessor.pkl",      # path to store preprocessor 
    encoding="utf-8",                                       # Optional parameters passed to read_csv
    delimiter=","                                           # Optional (if CSV uses different delimiter)
)
